# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('italy-covid-daywise.csv')

# %%
df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        248 non-null    object
#  1   new_cases   248 non-null    float64
#  2   new_deaths  248 non-null    float64
#  3   new_tests   135 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#          new_cases  new_deaths     new_tests
# count   248.000000  248.000000    135.000000
# mean   1094.818548  143.133065  31699.674074
# std    1554.508002  227.105538  11622.209757
# min    -148.000000  -31.000000   7841.000000
# 25%     123.000000    3.000000  25259.000000
# 50%     342.000000   17.000000  29545.000000
# 75%    1371.750000  175.250000  37711.000000
# max    6557.000000  971.000000  95273.000000

# %%
df[['date','new_cases']]
# Out:
#            date  new_cases
# 0    2019-12-31        0.0
# 1    2020-01-01        0.0
# 2    2020-01-02        0.0
# 3    2020-01-03        0.0
# 4    2020-01-04        0.0
# ..          ...        ...
# 243  2020-08-30     1444.0
# 244  2020-08-31     1365.0
# 245  2020-09-01      996.0
# 246  2020-09-02      975.0
# 247  2020-09-03     1326.0
#
# [248 rows x 2 columns]

# %%
df_copy = df.copy() #this will copy df in copy variable

# %%
df_copy
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
df_copy.head()
# Out:
#          date  new_cases  new_deaths  new_tests
# 0  2019-12-31        0.0         0.0        NaN
# 1  2020-01-01        0.0         0.0        NaN
# 2  2020-01-02        0.0         0.0        NaN
# 3  2020-01-03        0.0         0.0        NaN
# 4  2020-01-04        0.0         0.0        NaN

# %%
df_copy.tail()
# Out:
#            date  new_cases  new_deaths  new_tests
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN

# %%
df_copy.at[0,'new_tests']
# Out:
# nan

# %%
df_copy['new_tests'][0:100]
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#       ..
# 95   NaN
# 96   NaN
# 97   NaN
# 98   NaN
# 99   NaN
# Name: new_tests, Length: 100, dtype: float64

# %%
df_copy.new_tests.first_valid_index()
# Out:
# 111

# %%
df_copy['new_tests'].first_valid_index()
# Out:
# 111

# %%
df_copy.iloc[111]
# Out:
# date          2020-04-20
# new_cases         3047.0
# new_deaths         433.0
# new_tests         7841.0
# Name: 111, dtype: object

# %%
df_copy.iloc[110:113]
# Out:
#            date  new_cases  new_deaths  new_tests
# 110  2020-04-19     3491.0       480.0        NaN
# 111  2020-04-20     3047.0       433.0     7841.0
# 112  2020-04-21     2256.0       454.0    28095.0

# %%
df_copy.sample(20)
# Out:
#            date  new_cases  new_deaths  new_tests
# 233  2020-08-20      642.0         7.0    49662.0
# 12   2020-01-12        0.0         0.0        NaN
# 8    2020-01-08        0.0         0.0        NaN
# 164  2020-06-12      379.0        53.0    37651.0
# 225  2020-08-12      412.0         6.0    27330.0
# 9    2020-01-09        0.0         0.0        NaN
# 136  2020-05-15      992.0       262.0    39027.0
# 187  2020-07-05      235.0        21.0    21166.0
# 226  2020-08-13      476.0        10.0    25629.0
# 135  2020-05-14      888.0       195.0    41131.0
# 119  2020-04-28     1739.0       333.0    37554.0
# 107  2020-04-16     2667.0       578.0        NaN
# 144  2020-05-23      652.0       130.0    42579.0
# 146  2020-05-25      531.0        50.0    20676.0
# 114  2020-04-23     3370.0       437.0    37083.0
# 235  2020-08-22      947.0         9.0    46613.0
# 16   2020-01-16        0.0         0.0        NaN
# 143  2020-05-22      642.0       156.0    42987.0
# ...

# %%
#getting total number of cases
total_number_of_cases = df_copy['new_cases'].sum()
print(total_number_of_cases)
# Out:
# 271515.0

# %%
#getting total number of deaths
total_number_of_deaths = df_copy['new_deaths'].sum()
print(total_number_of_deaths)
# Out:
# 35497.0

# %%
# getting total number of tests
total_number_of_tests = df_copy['new_tests'].sum()
print(total_number_of_tests)
# Out:
# 4279456.0

# %%
# rate of deaths
death_rate = (total_number_of_deaths/total_number_of_cases)*100
print('Death rate for Italy is {:.2f}%'.format(death_rate))
# Out:
# Death rate for Italy is 13.07%

# %% [raw]
# A total of 935310 tests were done before the tests reports were published in publiv

# %%
initial_tests = 935310
total_tests_done = total_number_of_tests + initial_tests

# %%
print(f"total number of tests are {total_tests_done}")
# Out:
# total number of tests are 5214766.0

# %%
df_copy
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
high_case = df_copy['new_cases'] >= 1000

# %%
high_case
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 243     True
# 244     True
# 245    False
# 246    False
# 247     True
# Name: new_cases, Length: 248, dtype: bool

# %%
df_copy[high_case]
# Out:
#            date  new_cases  new_deaths  new_tests
# 68   2020-03-08     1247.0        36.0        NaN
# 69   2020-03-09     1492.0       133.0        NaN
# 70   2020-03-10     1797.0        98.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 73   2020-03-13     2651.0       189.0        NaN
# ..          ...        ...         ...        ...
# 241  2020-08-28     1409.0         5.0    65135.0
# 242  2020-08-29     1460.0         9.0    64294.0
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 247  2020-09-03     1326.0         6.0        NaN
#
# [72 rows x 4 columns]

# %%
high_deahts = df_copy['new_deaths'] >= 100

# %%
df_copy[high_deahts]
# Out:
#            date  new_cases  new_deaths  new_tests
# 69   2020-03-09     1492.0       133.0        NaN
# 71   2020-03-11      977.0       167.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 73   2020-03-13     2651.0       189.0        NaN
# 74   2020-03-14     2547.0       252.0        NaN
# ..          ...        ...         ...        ...
# 144  2020-05-23      652.0       130.0    42579.0
# 145  2020-05-24      669.0       119.0    34206.0
# 149  2020-05-28      584.0       117.0    39838.0
# 152  2020-05-31      416.0       111.0    28948.0
# 229  2020-08-16      629.0       158.0    22470.0
#
# [78 rows x 4 columns]

# %%
(total_number_of_cases / total_tests_done)*100
# Out:
# 5.206657403227681

# %%
df_copy['positivity_rate'] = (df_copy['new_cases']/df_copy['new_tests'])*100

# %%
df_copy
# Out:
#            date  new_cases  new_deaths  new_tests  positivity_rate
# 0    2019-12-31        0.0         0.0        NaN              NaN
# 1    2020-01-01        0.0         0.0        NaN              NaN
# 2    2020-01-02        0.0         0.0        NaN              NaN
# 3    2020-01-03        0.0         0.0        NaN              NaN
# 4    2020-01-04        0.0         0.0        NaN              NaN
# ..          ...        ...         ...        ...              ...
# 243  2020-08-30     1444.0         1.0    53541.0         2.696999
# 244  2020-08-31     1365.0         4.0    42583.0         3.205505
# 245  2020-09-01      996.0         6.0    54395.0         1.831051
# 246  2020-09-02      975.0         8.0        NaN              NaN
# 247  2020-09-03     1326.0         6.0        NaN              NaN
#
# [248 rows x 5 columns]

# %%
df_copy.iloc[112]
# Out:
# date               2020-04-21
# new_cases              2256.0
# new_deaths              454.0
# new_tests             28095.0
# positivity_rate      8.029899
# Name: 112, dtype: object

# %%
(total_number_of_deaths / total_tests_done)*100
# Out:
# 0.6807016844092333

# %%
df_copy['death_rate'] = (df_copy['new_deaths'] / df_copy['new_tests'])*100

# %%
df_copy
# Out:
#            date  new_cases  new_deaths  new_tests  positivity_rate  death_rate
# 0    2019-12-31        0.0         0.0        NaN              NaN         NaN
# 1    2020-01-01        0.0         0.0        NaN              NaN         NaN
# 2    2020-01-02        0.0         0.0        NaN              NaN         NaN
# 3    2020-01-03        0.0         0.0        NaN              NaN         NaN
# 4    2020-01-04        0.0         0.0        NaN              NaN         NaN
# ..          ...        ...         ...        ...              ...         ...
# 243  2020-08-30     1444.0         1.0    53541.0         2.696999    0.001868
# 244  2020-08-31     1365.0         4.0    42583.0         3.205505    0.009393
# 245  2020-09-01      996.0         6.0    54395.0         1.831051    0.011030
# 246  2020-09-02      975.0         8.0        NaN              NaN         NaN
# 247  2020-09-03     1326.0         6.0        NaN              NaN         NaN
#
# [248 rows x 6 columns]

# %%
df_copy['new_cases'].mean()
# Out:
# 1094.8185483870968

# %%
df_copy['new_deaths'].mean()
# Out:
# 143.13306451612902

# %%
df_copy['new_tests'].mean()
# Out:
# 31699.674074074075

# %%
df_copy.head()
# Out:
#          date  new_cases  new_deaths  new_tests  positivity_rate  death_rate
# 0  2019-12-31        0.0         0.0        NaN              NaN         NaN
# 1  2020-01-01        0.0         0.0        NaN              NaN         NaN
# 2  2020-01-02        0.0         0.0        NaN              NaN         NaN
# 3  2020-01-03        0.0         0.0        NaN              NaN         NaN
# 4  2020-01-04        0.0         0.0        NaN              NaN         NaN

# %%
df_copy['date']
# Out:
# 0      2019-12-31
# 1      2020-01-01
# 2      2020-01-02
# 3      2020-01-03
# 4      2020-01-04
#           ...
# 243    2020-08-30
# 244    2020-08-31
# 245    2020-09-01
# 246    2020-09-02
# 247    2020-09-03
# Name: date, Length: 248, dtype: object

# %%
df_copy['date'] = pd.to_datetime(df_copy['date'])

# %%
df_copy['date']
# Out:
# 0     2019-12-31
# 1     2020-01-01
# 2     2020-01-02
# 3     2020-01-03
# 4     2020-01-04
#          ...
# 243   2020-08-30
# 244   2020-08-31
# 245   2020-09-01
# 246   2020-09-02
# 247   2020-09-03
# Name: date, Length: 248, dtype: datetime64[ns]

# %%
df_copy.head()
# Out:
#         date  new_cases  new_deaths  new_tests  positivity_rate  death_rate
# 0 2019-12-31        0.0         0.0        NaN              NaN         NaN
# 1 2020-01-01        0.0         0.0        NaN              NaN         NaN
# 2 2020-01-02        0.0         0.0        NaN              NaN         NaN
# 3 2020-01-03        0.0         0.0        NaN              NaN         NaN
# 4 2020-01-04        0.0         0.0        NaN              NaN         NaN

# %%
df_copy['year'] = pd.DatetimeIndex(df_copy['date']).year

# %%
df_copy['month'] = pd.DatetimeIndex(df_copy['date']).month

# %%
df_copy['weekday'] = pd.DatetimeIndex(df_copy['date']).weekday

# %%
df_copy.head()
# Out:
#         date  new_cases  new_deaths  new_tests  positivity_rate  death_rate  \
# 0 2019-12-31        0.0         0.0        NaN              NaN         NaN
# 1 2020-01-01        0.0         0.0        NaN              NaN         NaN
# 2 2020-01-02        0.0         0.0        NaN              NaN         NaN
# 3 2020-01-03        0.0         0.0        NaN              NaN         NaN
# 4 2020-01-04        0.0         0.0        NaN              NaN         NaN
#
#    year  month  weekday
# 0  2019     12        1
# 1  2020      1        2
# 2  2020      1        3
# 3  2020      1        4
# 4  2020      1        5

# %% [raw]
# 0-Monday
# 1-Tuesday
# 2-wednesday
# 3-Thursday
# 4-Friday
# 5-Saturday
# 6-Sunday

# %% [markdown]
# Total cases detected on day basis

# %%
weekday_cases = pd.DataFrame(
    {
        'Day':[
            'Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'
        ],
        'Number of cases':[
            df_copy[df_copy['weekday'] == 0]['new_cases'].sum(),
            df_copy[df_copy['weekday'] == 1]['new_cases'].sum(),
            df_copy[df_copy['weekday'] == 2]['new_cases'].sum(),
            df_copy[df_copy['weekday'] == 3]['new_cases'].sum(),
            df_copy[df_copy['weekday'] == 4]['new_cases'].sum(),
            df_copy[df_copy['weekday'] == 5]['new_cases'].sum(),
            df_copy[df_copy['weekday'] == 6]['new_cases'].sum(),
        ]
    }
)

# %%
weekday_cases
# Out:
#          Day  Number of cases
# 0     Monday          38820.0
# 1    Tuesday          33071.0
# 2  Wednesday          33383.0
# 3   Thursday          39444.0
# 4     Friday          41640.0
# 5   Saturday          41503.0
# 6     Sunday          43654.0

# %% [markdown]
# Deaths per day

# %%
weekday_deaths = pd.DataFrame(
    {
        'Day':[
            'Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'
        ],
        'Number of cases':[
            df_copy[df_copy['weekday'] == 0]['new_deaths'].sum(),
            df_copy[df_copy['weekday'] == 1]['new_deaths'].sum(),
            df_copy[df_copy['weekday'] == 2]['new_deaths'].sum(),
            df_copy[df_copy['weekday'] == 3]['new_deaths'].sum(),
            df_copy[df_copy['weekday'] == 4]['new_deaths'].sum(),
            df_copy[df_copy['weekday'] == 5]['new_deaths'].sum(),
            df_copy[df_copy['weekday'] == 6]['new_deaths'].sum(),
        ]
    }
)

# %%
weekday_deaths
# Out:
#          Day  Number of cases
# 0     Monday           4368.0
# 1    Tuesday           4678.0
# 2  Wednesday           5211.0
# 3   Thursday           5093.0
# 4     Friday           5071.0
# 5   Saturday           5495.0
# 6     Sunday           5581.0

# %% [markdown]
# Fetching data from month of May

# %%
df_copy.head()
# Out:
#         date  new_cases  new_deaths  new_tests  positivity_rate  death_rate  \
# 0 2019-12-31        0.0         0.0        NaN              NaN         NaN
# 1 2020-01-01        0.0         0.0        NaN              NaN         NaN
# 2 2020-01-02        0.0         0.0        NaN              NaN         NaN
# 3 2020-01-03        0.0         0.0        NaN              NaN         NaN
# 4 2020-01-04        0.0         0.0        NaN              NaN         NaN
#
#    year  month  weekday
# 0  2019     12        1
# 1  2020      1        2
# 2  2020      1        3
# 3  2020      1        4
# 4  2020      1        5

# %%
may_data = df_copy[df_copy['month'] == 5]

# %%
may_data
# Out:
#           date  new_cases  new_deaths  new_tests  positivity_rate  death_rate  \
# 122 2020-05-01     1872.0       285.0    43732.0         4.280618    0.651697
# 123 2020-05-02     1965.0       269.0    31231.0         6.291825    0.861324
# 124 2020-05-03     1900.0       474.0    27047.0         7.024809    1.752505
# 125 2020-05-04     1389.0       174.0    22999.0         6.039393    0.756555
# 126 2020-05-05     1221.0       195.0    32211.0         3.790631    0.605383
# 127 2020-05-06     1075.0       236.0    37771.0         2.846099    0.624818
# 128 2020-05-07     1444.0       369.0    13665.0        10.567142    2.700329
# 129 2020-05-08     1401.0       274.0    45428.0         3.084001    0.603152
# 130 2020-05-09     1327.0       243.0    36091.0         3.676817    0.673298
# 131 2020-05-10     1083.0       194.0    31384.0         3.450803    0.618149
# 132 2020-05-11      802.0       165.0    25823.0         3.105758    0.638965
# ...

# %%
may_data[['new_cases','new_deaths','new_tests']]
# Out:
#      new_cases  new_deaths  new_tests
# 122     1872.0       285.0    43732.0
# 123     1965.0       269.0    31231.0
# 124     1900.0       474.0    27047.0
# 125     1389.0       174.0    22999.0
# 126     1221.0       195.0    32211.0
# 127     1075.0       236.0    37771.0
# 128     1444.0       369.0    13665.0
# 129     1401.0       274.0    45428.0
# 130     1327.0       243.0    36091.0
# 131     1083.0       194.0    31384.0
# 132      802.0       165.0    25823.0
# 133      744.0       179.0    39620.0
# 134     1402.0       172.0    37049.0
# 135      888.0       195.0    41131.0
# 136      992.0       262.0    39027.0
# 137      789.0       242.0    40657.0
# 138      875.0       153.0    33505.0
# 139      675.0       145.0    26101.0
# 140      451.0        99.0    40226.0
# 141      813.0       162.0    38617.0
# 142      665.0       161.0    40644.0
# 143      642.0       156.0    42987.0
# 144      652.0       130.0    42579.0
# 145      669.0       119.0    34206.0
# ...

# %%
may_data['new_cases'].sum()
# Out:
# 29073.0

# %%
may_data['new_deaths'].sum()
# Out:
# 5658.0

# %%
may_data['new_tests'].sum()
# Out:
# 1078720.0

# %%
may_data = may_data[['new_tests','new_deaths','new_cases']]

# %%
may_data.sum()
# Out:
# new_tests     1078720.0
# new_deaths       5658.0
# new_cases       29073.0
# dtype: float64

# %% [markdown]
# Grouping based on months

# %%
df_month = df_copy.groupby('month')[['new_cases','new_deaths','new_tests']]

# %%
df_month.sum()
# Out:
#        new_cases  new_deaths  new_tests
# month
# 1            3.0         0.0        0.0
# 2          885.0        21.0        0.0
# 3       100851.0     11570.0        0.0
# 4       101852.0     16091.0   419591.0
# 5        29073.0      5658.0  1078720.0
# 6         7772.0      1404.0   830354.0
# 7         6722.0       388.0   797692.0
# 8        21060.0       345.0  1098704.0
# 9         3297.0        20.0    54395.0
# 12           0.0         0.0        0.0

# %%
df_weekday = df_copy.groupby('weekday')[['new_cases','new_deaths','new_tests']]

# %%
df_weekday.sum()
# Out:
#          new_cases  new_deaths  new_tests
# weekday
# 0          38820.0      4368.0   396534.0
# 1          33071.0      4678.0   623338.0
# 2          33383.0      5211.0   658639.0
# 3          39444.0      5093.0   655283.0
# 4          41640.0      5071.0   745288.0
# 5          41503.0      5495.0   657200.0
# 6          43654.0      5581.0   543174.0

# %%
df_weekday.mean()
# Out:
#            new_cases  new_deaths     new_tests
# weekday
# 0        1109.142857  124.800000  19826.700000
# 1         918.638889  129.944444  31166.900000
# 2         927.305556  144.750000  34665.210526
# 3        1095.666667  141.472222  34488.578947
# 4        1189.714286  144.885714  39225.684211
# 5        1185.800000  157.000000  34589.473684
# 6        1247.257143  159.457143  28588.105263
